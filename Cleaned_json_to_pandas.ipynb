# %%
import pandas as pd
import json
from pandas.io.json import json_normalize 


with open('C:/Users/20193623/Desktop/DBL Data Challange/cleaned_tweets/test.json', 'r') as f:
    d = json.load(f) 

df = json_normalize(d)

# %%
df.head()
# Out:
#    coordinates coordinates.coordinates coordinates.type  \
# 0          NaN                     NaN              NaN
# 1          NaN                     NaN              NaN
# 2          NaN                     NaN              NaN
# 3          NaN                     NaN              NaN
# 4          NaN                     NaN              NaN
#
#                        created_at  delete.status.id delete.status.id_str  \
# 0  Wed May 22 12:20:00 +0000 2019               NaN                  NaN
# 1  Wed May 22 12:20:01 +0000 2019               NaN                  NaN
# 2  Wed May 22 12:20:02 +0000 2019               NaN                  NaN
# 3  Wed May 22 12:20:12 +0000 2019               NaN                  NaN
# 4  Wed May 22 12:20:28 +0000 2019               NaN                  NaN
#
#    delete.status.user_id delete.status.user_id_str delete.timestamp_ms  \
# 0                    NaN                       NaN                 NaN
# ...
